# %%
# here we are going to  analyise the data and get the proper key insghts what we can make

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#           Region      Sub_Region         Country Continent_Group  \
# 0          India      South Asia           India            Asia
# 1      Indonesia  Southeast Asia       Indonesia            Asia
# 2       Pakistan      South Asia        Pakistan            Asia
# 3     Bangladesh      South Asia      Bangladesh            Asia
# 4          Japan       East Asia           Japan            Asia
# 5    South Korea       East Asia     South Korea            Asia
# 6          China       East Asia           China            Asia
# 7    Philippines  Southeast Asia     Philippines            Asia
# 8       Thailand  Southeast Asia        Thailand            Asia
# 9        Vietnam  Southeast Asia         Vietnam            Asia
# 10      Malaysia  Southeast Asia        Malaysia            Asia
# 11         Nepal      South Asia           Nepal            Asia
# 12     Sri Lanka      South Asia       Sri Lanka            Asia
# ...

# %% [markdown]
# ### DATA ANALYSIS

# %%
internet_average_usage = np.mean (df['Avg_Daily_YouTube_Hours'])
(internet_average_usage)
# Out:
# np.float64(2.126829268292683)

# %%
avg_views_world = np.mean(df['Average_Monthly_Views_Billion'])
avg_views_world
# Out:
# np.float64(30.926829268292682)

# %%
avg_int_users = np.mean(df['Internet_Users_Million'])
avg_int_users
# Out:
# np.float64(113.95121951219512)

# %%
#max subs in the world 
max_subs = np.argmax(df['Top_Creator_Subs_Million'])
max_subs
Top_creater = np.max(df['Top_Creator_Subs_Million'])
Top_creater
name = df.at[17,'Top_Creator']
name
print(f"The most famous youtube with over {Top_creater} Million Subs  is {name}")
# Out:
# The most famous youtube with over 390.0 Million Subs  is MrBeast

# %%
#Country and there most famous youtuber 
Top_creator = df[['Country','Top_Creator']]
#Top_creator

# %%
#country and their Internet users in millions 
Usage = df[['Country','Internet_Users_Million']]

# %% [markdown]
# # Asian creator data

# %%
asian_creator = df.loc[0:15]

# %%
#ASIAN MOST FAMOUS YOUTUBER 
np.argmax(asian_creator['Top_Creator_Subs_Million'])
top_creator = asian_creator.at[0,'Top_Creator']
Top_youtuber = print(f"The most youtube channel in india is {top_creater} with over {np.max(asian_creater['Top_Creator_Subs_Million'])}")
# Out:
# The most youtube channel in india is T-Series with over 290.0

# %%
#avg monthly views of the asia 
views = int(np.sum(asian_creator['Average_Monthly_Views_Billion']))
monthly_views = print(f'Average monthly views of the asia is {views} billion')
# Out:
# Average monthly views of the asia is 640 billion

# %%
#total  internet user of the asia 
internet_users = int(np.sum(asian_creator['Internet_Users_Million']))
Total_users = print(f'The Total internet users in Asia is {internet_users} Million')
Total_users
# Out:
# The Total internet users in Asia is 3058 Million

# %%
# coutries in the asia 
countries  =list( asian_creator['Region'])

countries_asia = print(f'The countries that are includes in asia region is {countries}')
# Out:
# The countries that are includes in asia region is ['India', 'Indonesia', 'Pakistan', 'Bangladesh', 'Japan', 'South Korea', 'China', 'Philippines', 'Thailand', 'Vietnam', 'Malaysia', 'Nepal', 'Sri Lanka', 'Saudi Arabia', 'UAE', 'Turkey']

# %%
#total population 
Total_P = int(np.sum(asian_creator['Population_Million']))
Total_poputtion  = print(f'Total popultation of the Asia is {Total_P} million')
# Out:
# Total popultation of the Asia is 4225 million

# %% [markdown]
# # Rest of the World

# %%
world_creator = df.loc[16:40]
world_creator
# Out:
#           Region      Sub_Region         Country Continent_Group  \
# 16        Russia  Eastern Europe          Russia   Rest of World
# 17           USA   North America   United States   Rest of World
# 18        Canada   North America          Canada   Rest of World
# 19        Mexico   North America          Mexico   Rest of World
# 20        Brazil   South America          Brazil   Rest of World
# 21     Argentina   South America       Argentina   Rest of World
# 22            UK          Europe  United Kingdom   Rest of World
# 23       Germany          Europe         Germany   Rest of World
# 24        France          Europe          France   Rest of World
# 25         Spain          Europe           Spain   Rest of World
# 26         Italy          Europe           Italy   Rest of World
# 27       Nigeria          Africa         Nigeria   Rest of World
# 28  South Africa          Africa    South Africa   Rest of World
# ...

# %%
np.argmax(world_creator['Top_Creator_Subs_Million'])
# Out:
# np.int64(1)

# %%
#top creator 
top_creator = world_creator.at[17,'Top_Creator']
Top_youtuber = print(f"The world most famous youtuber is {top_creator} not including the asia with over {int(np.max(world_creator['Top_Creator_Subs_Million']))} million")
# Out:
# The world most famous youtuber is MrBeast not including the asia with over 390 million

# %%
conuntries = list(world_creator['Region'])
Country  = print (f'The  number of country participating is 25 and they are {countries}')
# Out:
# The  number of country participating is 25 and they are ['India', 'Indonesia', 'Pakistan', 'Bangladesh', 'Japan', 'South Korea', 'China', 'Philippines', 'Thailand', 'Vietnam', 'Malaysia', 'Nepal', 'Sri Lanka', 'Saudi Arabia', 'UAE', 'Turkey']

# %%
#avg monthly views in Rest of the world 
views =int( np.sum(world_creator['Average_Monthly_Views_Billion']))
Avg_views = print(f'The average monthly Views of the Rest of the world is {views} Billion')
Avg_views
# Out:
# The average monthly Views of the Rest of the world is 628 Billion

# %%
#Total internet users in the world 
users =int( np.sum(world_creator['Internet_Users_Million']))
Total_internet_users = print(f'Total internet users of the Rest of the world is {users} million')
# Out:
# Total internet users of the Rest of the world is 1614 million

# %%
#Total popoultion of 25 countries 
T_population = int(np.sum(world_creator['Population_Million']))
Total_population = print(f'The popultaion of the 25 countries is {T_population} million')
# Out:
# The popultaion of the 25 countries is 1963 million
